# %%
import sys
sys.path.append("/Users/davidemoretti/Desktop/MawileBot/home/MawileBot/src")
from BeatlesBoy_utils import pokemon_utility, filter_team

# %%
team = [
    ['Monferno', 29],
    ['Abomasnow', 44],
    ['Riolu', 27],
    ['Kirlia', 21],
    ['Absol', 24],
    ['Miltank', 71],
    ['Applin', 37], 
    ['Mantyke', 18],
    ['Wimpod', 8]
]

# %%
for poke,liv in team:
    print ('\n',poke, liv)
    print('FINAL UTILITY', await pokemon_utility(poke, liv,  data = {"lvlup": False, "catch": False, "drop": False}))
# Out:
#  Monferno 29
# base utility =  6.8990322580645165
# malus inallenabile =  0
# next gym bonus =  0
# FINAL UTILITY 6.9
#
#  Abomasnow 44
# Mega BOOST!
# base utility =  7.461935483870967
# malus inallenabile =  0
# next gym bonus =  0
# FINAL UTILITY 7.46
#
#  Riolu 27
# Mega BOOST!
# base utility =  7.301935483870967
# malus inallenabile =  -0.3
# next gym bonus =  0
# FINAL UTILITY 7.0
#
#  Kirlia 21
# Mega BOOST!
# base utility =  7.042903225806452
# malus inallenabile =  -0.6
# next gym bonus =  0
# FINAL UTILITY 6.44
#
#  Absol 24
# base utility =  6.082903225806451
# malus inallenabile =  0
# next gym bonus =  0
# FINAL UTILITY 6.08
#
#  Miltank 71
# base utility =  7.662258064516128
# malus inallenabile =  0
# next gym bonus =  0
# FINAL UTILITY 7.66
#
#  Applin 37
# base utility =  7.206774193548386
# malus inallenabile =  0
# next gym bonus =  0
# FINAL UTILITY 7.21
#
#  Mantyke 18
# base utility =  6.015806451612903
# malus inallenabile =  -0.44999999999999996
# next gym bonus =  0
# FINAL UTILITY 5.57
#
#  Wimpod 8
# base utility =  6.223870967741935
# malus inallenabile =  -1.2500000000000004
# next gym bonus =  0
# FINAL UTILITY 4.97

# %%
for poke,liv in team:
    print ('\n',poke, liv)
    print('FINAL UTILITY', await pokemon_utility(poke, liv,  data = {"lvlup": True, "catch": False, "drop": False}))
# Out:
#  Monferno 29
# base utility =  6.8990322580645165
# malus inallenabile =  0
# next gym bonus =  0
# FINAL UTILITY 6.9
#
#  Abomasnow 44
# Mega BOOST!
# base utility =  7.461935483870967
# malus inallenabile =  0
# next gym bonus =  0
# FINAL UTILITY 7.46
#
#  Riolu 27
# Mega BOOST!
# base utility =  7.301935483870967
# malus inallenabile =  -0.3
# next gym bonus =  8
# FINAL UTILITY 15.0
#
#  Kirlia 21
# Mega BOOST!
# base utility =  7.042903225806452
# malus inallenabile =  -0.6
# next gym bonus =  0
# FINAL UTILITY 6.44
#
#  Absol 24
# base utility =  6.082903225806451
# malus inallenabile =  0
# next gym bonus =  0
# FINAL UTILITY 6.08
#
#  Miltank 71
# base utility =  7.662258064516128
# malus inallenabile =  0
# next gym bonus =  0
# FINAL UTILITY 7.66
#
#  Applin 37
# base utility =  7.206774193548386
# malus inallenabile =  0
# next gym bonus =  8
# FINAL UTILITY 15.21
#
#  Mantyke 18
# base utility =  6.015806451612903
# malus inallenabile =  -0.44999999999999996
# next gym bonus =  0
# FINAL UTILITY 5.57
#
#  Wimpod 8
# base utility =  6.223870967741935
# malus inallenabile =  -1.2500000000000004
# next gym bonus =  0
# FINAL UTILITY 4.97

# %%
useful, useless, lvl100 = await filter_team(team, nilb = False, data_filter = {"lvlup": True, "drop": True})
print(useful, useless, lvl100)
# Out:
# base utility =  6.8990322580645165
# malus inallenabile =  0
# next gym bonus =  0
# Mega BOOST!
# base utility =  7.461935483870967
# malus inallenabile =  0
# next gym bonus =  0
# Mega BOOST!
# base utility =  7.301935483870967
# malus inallenabile =  -0.3
# next gym bonus =  0
# Mega BOOST!
# base utility =  7.042903225806452
# malus inallenabile =  -0.6
# next gym bonus =  0
# base utility =  6.082903225806451
# malus inallenabile =  0
# next gym bonus =  0
# base utility =  7.662258064516128
# malus inallenabile =  0
# next gym bonus =  0
# base utility =  7.206774193548386
# malus inallenabile =  0
# next gym bonus =  0
# base utility =  6.015806451612903
# malus inallenabile =  -0.44999999999999996
# next gym bonus =  0
# base utility =  6.223870967741935
# malus inallenabile =  -1.2500000000000004
# next gym bonus =  0
# base utility =  6.8990322580645165
# malus inallenabile =  0
# next gym bonus =  200
# Mega BOOST!
# base utility =  7.461935483870967
# malus inallenabile =  0
# next gym bonus =  200
# Mega BOOST!
# base utility =  7.301935483870967
# malus inallenabile =  -0.3
# next gym bonus =  8
# Mega BOOST!
# base utility =  7.042903225806452
# malus inallenabile =  -0.6
# next gym bonus =  0
# base utility =  6.082903225806451
# malus inallenabile =  0
# next gym bonus =  200
# base utility =  7.662258064516128
# malus inallenabile =  0
# next gym bonus =  200
# base utility =  7.206774193548386
# malus inallenabile =  0
# next gym bonus =  8
# base utility =  6.015806451612903
# malus inallenabile =  -0.44999999999999996
# next gym bonus =  0
# base utility =  6.223870967741935
# malus inallenabile =  -1.2500000000000004
# next gym bonus =  0
# [('Miltank', 71, 207.66, 348, 6), ('Abomasnow', 44, 207.46, 217, 2), ('Monferno', 29, 206.9, 117, 1), ('Absol', 24, 206.08, 114, 5), ('Applin', 37, 15.21, 96, 7), ('Riolu', 27, 15.0, 77, 3)] [('Kirlia', 21, 6.44, 58, 4), ('Mantyke', 18, 5.57, 62, 8), ('Wimpod', 8, 4.97, 18, 9)] []
