# %%
import sys
sys.path.append("/Users/davidemoretti/Desktop/MawileBot/home/MawileBot/src")
from BeatlesBoy_utils import pokemon_utility

# %%
team = [
    ['Chimchar', 6],
    ['Skitty', 5],
    ['Luvdisc', 4],
    ['Cherubi', 7],
    ['Absol', 6],
    ['Miltank', 7],
    ['Cleffa', 5], 
    ['Mantyke', 6]
]

# %%
for poke,liv in team:
    print ('\n',poke, liv)
    print('FINAL UTILITY', await pokemon_utility(poke, liv,  data = {"lvlup": False, "catch": False, "drop": False}))
# Out:
#  Chimchar 6
# Loading mega from: ./home/MawileBot/src/BeatlesBoy_info.json
# base utility =  6.209032258064516
# malus inallenabile =  0
# next gym bonus =  0
# FINAL UTILITY 6.21
#
#  Skitty 5
# Loading mega from: ./home/MawileBot/src/BeatlesBoy_info.json
# base utility =  5.230645161290322
# malus inallenabile =  0
# next gym bonus =  0
# FINAL UTILITY 5.23
#
#  Luvdisc 4
# Loading mega from: ./home/MawileBot/src/BeatlesBoy_info.json
# base utility =  5.144193548387097
# malus inallenabile =  0
# next gym bonus =  0
# FINAL UTILITY 5.14
#
#  Cherubi 7
# Loading mega from: ./home/MawileBot/src/BeatlesBoy_info.json
# base utility =  5.46
# malus inallenabile =  0
# next gym bonus =  0
# FINAL UTILITY 5.46
#
#  Absol 6
# Loading mega from: ./home/MawileBot/src/BeatlesBoy_info.json
# base utility =  5.542903225806451
# bonus fullyevo = +1
# malus inallenabile =  0
# next gym bonus =  0
# FINAL UTILITY 6.54
#
#  Miltank 7
# Loading mega from: ./home/MawileBot/src/BeatlesBoy_info.json
# base utility =  5.742258064516128
# bonus fullyevo = +1
# malus inallenabile =  0
# next gym bonus =  0
# FINAL UTILITY 6.74
#
#  Cleffa 5
# Loading mega from: ./home/MawileBot/src/BeatlesBoy_info.json
# Mega BOOST!
# base utility =  6.16774193548387
# malus inallenabile =  0
# next gym bonus =  0
# FINAL UTILITY 6.17
#
#  Mantyke 6
# Loading mega from: ./home/MawileBot/src/BeatlesBoy_info.json
# base utility =  5.655806451612903
# malus inallenabile =  0
# next gym bonus =  0
# FINAL UTILITY 5.66

# %%
for poke,liv in team:
    print ('\n',poke, liv)
    print('FINAL UTILITY', await pokemon_utility(poke, liv,  data = {"lvlup": False, "catch": True, "drop": False}))
# Out:
#  Chimchar 6
# Loading mega from: ./home/MawileBot/src/BeatlesBoy_info.json
# base utility =  6.209032258064516
# malus inallenabile =  0
# Loading team from: ./home/MawileBot/src/BeatlesBoy_info.json
# next gym bonus =  0
# FINAL UTILITY 6.21
#
#  Skitty 5
# Loading mega from: ./home/MawileBot/src/BeatlesBoy_info.json
# base utility =  5.230645161290322
# malus inallenabile =  -0.05
# Loading team from: ./home/MawileBot/src/BeatlesBoy_info.json
# next gym bonus =  0
# FINAL UTILITY 5.18
#
#  Luvdisc 4
# Loading mega from: ./home/MawileBot/src/BeatlesBoy_info.json
# base utility =  5.144193548387097
# malus inallenabile =  0
# Loading team from: ./home/MawileBot/src/BeatlesBoy_info.json
# next gym bonus =  0
# FINAL UTILITY 5.14
#
#  Cherubi 7
# Loading mega from: ./home/MawileBot/src/BeatlesBoy_info.json
# base utility =  5.46
# malus inallenabile =  0
# Loading team from: ./home/MawileBot/src/BeatlesBoy_info.json
# next gym bonus =  0
# FINAL UTILITY 5.46
#
#  Absol 6
# Loading mega from: ./home/MawileBot/src/BeatlesBoy_info.json
# base utility =  5.542903225806451
# bonus fullyevo = +1
# malus inallenabile =  0
# Loading team from: ./home/MawileBot/src/BeatlesBoy_info.json
# next gym bonus =  0
# FINAL UTILITY 6.54
#
#  Miltank 7
# Loading mega from: ./home/MawileBot/src/BeatlesBoy_info.json
# base utility =  5.742258064516128
# bonus fullyevo = +1
# malus inallenabile =  0
# Loading team from: ./home/MawileBot/src/BeatlesBoy_info.json
# next gym bonus =  0
# FINAL UTILITY 6.74
#
#  Cleffa 5
# Loading mega from: ./home/MawileBot/src/BeatlesBoy_info.json
# Mega BOOST!
# base utility =  6.16774193548387
# malus inallenabile =  -0.1
# Loading team from: ./home/MawileBot/src/BeatlesBoy_info.json
# next gym bonus =  0
# FINAL UTILITY 6.07
#
#  Mantyke 6
# Loading mega from: ./home/MawileBot/src/BeatlesBoy_info.json
# base utility =  5.655806451612903
# malus inallenabile =  0
# Loading team from: ./home/MawileBot/src/BeatlesBoy_info.json
# next gym bonus =  0
# FINAL UTILITY 5.66
