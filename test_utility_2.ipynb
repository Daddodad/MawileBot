# %%
import sys
sys.path.append("/Users/davidemoretti/Desktop/MawileBot/home/MawileBot/src")
from BeatlesBoy_utils import pokemon_utility, filter_team

# %%
team = [
    ['Chimchar', 6],
    ['Skitty', 5],
    ['Luvdisc', 6],
    ['Cherubi', 12],
    ['Absol', 11],
    ['Miltank', 20],
    ['Mantyke', 12], 
    ['Wimpod', 8],
    ['Cleffa', 5]
]

# %%
for poke,liv in team:
    print ('\n',poke, liv)
    print('FINAL UTILITY', await pokemon_utility(poke, liv,  data = {"lvlup": False, "catch": False, "drop": False}))
# Out:
#  Chimchar 6
# Loading mega from: ./home/MawileBot/src/BeatlesBoy_info.json
# base utility =  6.209032258064516
# malus inallenabile =  0
# next gym bonus =  0
# FINAL UTILITY 6.21
#
#  Skitty 5
# Loading mega from: ./home/MawileBot/src/BeatlesBoy_info.json
# base utility =  5.230645161290322
# malus inallenabile =  0
# next gym bonus =  0
# FINAL UTILITY 5.23
#
#  Luvdisc 6
# Loading mega from: ./home/MawileBot/src/BeatlesBoy_info.json
# base utility =  5.204193548387097
# malus inallenabile =  0
# next gym bonus =  0
# FINAL UTILITY 5.2
#
#  Cherubi 12
# Loading mega from: ./home/MawileBot/src/BeatlesBoy_info.json
# base utility =  5.61
# malus inallenabile =  0
# next gym bonus =  0
# FINAL UTILITY 5.61
#
#  Absol 11
# Loading mega from: ./home/MawileBot/src/BeatlesBoy_info.json
# base utility =  5.692903225806451
# bonus fullyevo = +1
# malus inallenabile =  0
# next gym bonus =  0
# FINAL UTILITY 6.69
#
#  Miltank 20
# Loading mega from: ./home/MawileBot/src/BeatlesBoy_info.json
# ...

# %%
for poke,liv in team:
    print ('\n',poke, liv)
    print('FINAL UTILITY', await pokemon_utility(poke, liv,  data = {"lvlup": True, "catch": False, "drop": False}))
# Out:
#  Chimchar 6
# Loading mega from: ./home/MawileBot/src/BeatlesBoy_info.json
# base utility =  6.209032258064516
# malus inallenabile =  0
# next gym bonus =  0
# FINAL UTILITY 6.21
#
#  Skitty 5
# Loading mega from: ./home/MawileBot/src/BeatlesBoy_info.json
# base utility =  5.230645161290322
# malus inallenabile =  0
# next gym bonus =  0
# FINAL UTILITY 5.23
#
#  Luvdisc 6
# Loading mega from: ./home/MawileBot/src/BeatlesBoy_info.json
# base utility =  5.204193548387097
# malus inallenabile =  0
# next gym bonus =  8
# FINAL UTILITY 13.2
#
#  Cherubi 12
# Loading mega from: ./home/MawileBot/src/BeatlesBoy_info.json
# base utility =  5.61
# malus inallenabile =  0
# next gym bonus =  0
# FINAL UTILITY 5.61
#
#  Absol 11
# Loading mega from: ./home/MawileBot/src/BeatlesBoy_info.json
# base utility =  5.692903225806451
# bonus fullyevo = +1
# malus inallenabile =  0
# next gym bonus =  0
# FINAL UTILITY 6.69
#
#  Miltank 20
# ...

# %%
await filter_team(team, nilb = True, data = {"lvlup": True, "catch": False, "drop": False})
# Out:
# Loading mega from: ./home/MawileBot/src/BeatlesBoy_info.json
# base utility =  6.209032258064516
# malus inallenabile =  0
# next gym bonus =  0
# Loading mega from: ./home/MawileBot/src/BeatlesBoy_info.json
# base utility =  5.230645161290322
# malus inallenabile =  0
# next gym bonus =  0
# Loading mega from: ./home/MawileBot/src/BeatlesBoy_info.json
# base utility =  5.204193548387097
# malus inallenabile =  0
# next gym bonus =  8
# Loading mega from: ./home/MawileBot/src/BeatlesBoy_info.json
# base utility =  5.61
# malus inallenabile =  0
# next gym bonus =  0
# Loading mega from: ./home/MawileBot/src/BeatlesBoy_info.json
# base utility =  5.692903225806451
# bonus fullyevo = +1
# malus inallenabile =  0
# next gym bonus =  0
# Loading mega from: ./home/MawileBot/src/BeatlesBoy_info.json
# base utility =  6.132258064516128
# bonus fullyevo = +1
# malus inallenabile =  0
# next gym bonus =  0
# Loading mega from: ./home/MawileBot/src/BeatlesBoy_info.json
# ...
