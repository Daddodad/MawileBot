# %%
OLD_LIVELLI_EVO = r"D:\Desktop_fake\MawileBot\home\utils\pokemon_evo_list\livelli_evo.txt"
NEW_LIVELLI_EVO = r"D:\Desktop_fake\MawileBot\home\utils\pokemon_evo_list\livellievo_new.txt"

# %%
with open(OLD_LIVELLI_EVO, "r") as old_file:
    old_lines = old_file.readlines()

with open(NEW_LIVELLI_EVO, "r") as new_file:
    new_lines = new_file.readlines()
    old_lines.append("\n") 
    for line in new_lines:
        if line not in old_lines:
            old_lines.append(line)

with open(OLD_LIVELLI_EVO, "w") as old_file:
    old_file.writelines(old_lines)
